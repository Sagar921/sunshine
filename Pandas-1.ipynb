# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
list =[1,2,3,-6,6.2,'data']
print(list)
# Out:
# [1, 2, 3, -6, 6.2, 'data']

# %%
sr1 = pd.Series(list)

# %%
print(sr1)
# Out:
# 0       1
# 1       2
# 2       3
# 3      -6
# 4     6.2
# 5    data
# dtype: object

# %%
type(sr1)
# Out:
# pandas.core.series.Series

# %%
sr2 = pd.Series([1,2,3])
sr2
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
empty = pd.Series([])
empty
# Out:
# C:\Users\sagar\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.
# Series([], dtype: float64)

# %%
sr3 = pd.Series([1,2,3,4], index= ['a','b','c','d'])
sr3
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
sr3 = pd.Series([1,2,3,4], index= ['a','b','c','d'], dtype='float')
sr3
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
sr3 = pd.Series([1,2,3,4], index= ['a','b','c','d'], dtype='float', name = 'data values')
sr3
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# Name: data values, dtype: float64

# %%
scalar_ =pd.Series(0.5)
scalar_
# Out:
# 0    0.5
# dtype: float64

# %%
scalar =pd.Series((0.5),index=(1,2,3))
scalar
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
dict={'a':1,'b':2}
sr4= pd.Series(dict)
sr4
# Out:
# a    1
# b    2
# dtype: int64

# %%
s5= pd.Series([1,2,3,4,5])
s5
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s5[1]
# Out:
# 2

# %%
s5[:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s5.max()
# Out:
# 5

# %%
s5.min()
# Out:
# 1

# %%
s5[s5>3]
# Out:
# 3    4
# 4    5
# dtype: int64

# %%
s5
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s6 =pd.Series([11,22,33,44,55])
s6
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
s5+s6
# Out:
# 0    12
# 1    24
# 2    36
# 3    48
# 4    60
# dtype: int64

# %%
s7 = pd.Series([1,2,3])
s7
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s7+s5
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    NaN
# 4    NaN
# dtype: float64

# %% [markdown]
# # How to create DataFrame

# %%
emt= pd.DataFrame()
print(emt)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst=['a','b','c']
print(lst)
# Out:
# ['a', 'b', 'c']

# %%
df1 = pd.DataFrame(lst)
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
ls =[[1,2,3,],[4,5,6],[7,8,9]]
ls
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df2 = pd.DataFrame(ls)
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dict1 ={'ID':[11,22,33]}
dict1
# Out:
# {'ID': [11, 22, 33]}

# %%
df3 = pd.DataFrame(dict1)
df3
# Out:
#    ID
# 0  11
# 1  22
# 2  33

# %%
dict1 ={'ID':[11,22,33],'SN':[1,2,3]}
dict1
# Out:
# {'ID': [11, 22, 33], 'SN': [1, 2, 3]}

# %%
df3= pd.DataFrame(dict1)
df3
# Out:
#    ID  SN
# 0  11   1
# 1  22   2
# 2  33   3

# %%
ls1 =[{'S':1,'b':2},{'S':3,'b':4}]
ls1
# Out:
# [{'S': 1, 'b': 2}, {'S': 3, 'b': 4}]

# %%
df4 = pd.DataFrame(ls1)
df4
# Out:
#    S  b
# 0  1  2
# 1  3  4

# %%
ls2 =[{'S':1,'b':2},{'S':3,'b':4,'c':5}]
df5=pd.DataFrame(ls2)
df5
# Out:
#    S  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
dict_sr = {'a':pd.Series([1,2,3]), 'b':pd.Series([4,5,6])}
df6 = pd.DataFrame(dict_sr)
df6
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df=pd.read_csv("D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\empl.csv")
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\sagar

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\sagar

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['SNo', 'Name', 'Age', 'City', 'Country', 'Salary'], dtype='object')

# %%
df=pd.read_csv("D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\empl.csv")
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df.head()
# Out:
#    SNo   Name   Age      City  Country   Salary
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
df=pd.read_csv("D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\empl.csv", index_col=['SNo'])
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1=pd.read_csv("D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\empl.csv")
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.head()
# Out:
#    SNo   Name   Age      City  Country   Salary
# 0    1    Tom  28.0   Toronto   Canada  20000.0
# 1    2    Lee  31.0   Edmonto   Canada   3900.0
# 2    3   Dave  34.0   Toronto   Canada   8000.0
# 3    4   Anik  26.0  HongKong     Asia  66672.0
# 4    5  kamal  30.0       NaN  America      NaN

# %%
df1.tail()
# Out:
#     SNo    Name   Age     City Country   Salary
# 17   19     Lee  31.0  Edmonto  Canada      NaN
# 18   20  Andrew  34.0    Congo  Africa  34432.0
# 19   21   soham  32.0   Angola  Africa  34534.0
# 20   22    Grig  26.0  Finland  Europe  33451.0
# 21   23   Kiara  27.0   London  Europe      NaN

# %%
df1=pd.read_csv("D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\empl.csv", na_filter=False)
df1
# Out:
#     SNo    Name  Age       City  Country Salary
# 0     1     Tom   28    Toronto   Canada  20000
# 1     2     Lee   31    Edmonto   Canada   3900
# 2     3    Dave   34    Toronto   Canada   8000
# 3     4    Anik   26   HongKong     Asia  66672
# 4     5   kamal   30        NaN  America    NaN
# 5     6    Geet  NaN   HongKong     Asia  30007
# 6     7  Steven   43    BayArea  America   8300
# 7     8     Ram   38  Hyderabad     Asia  54666
# 8     9    hari   50    newyork  America  67666
# 9    11    yami  NaN    newyork  America   8888
# 10   12    Anik   26   HongKong     Asia  66672
# 11   13   kamal   30        NaN  America  34344
# 12   14    Geet   22   HongKong     Asia  30007
# 13   15  Steven   43        NaN  America   8300
# 14   16     Ram   38  Hyderabad     Asia  54666
# 15   17    hari  NaN    newyork  America  67666
# 16   18    yami   27    newyork  America   8888
# 17   19     Lee   31    Edmonto   Canada    NaN
# 18   20  Andrew   34      Congo   Africa  34432
# ...

# %%
df1['Age'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: Age, dtype: bool

# %%
df1.isnull()
# Out:
#       SNo   Name    Age   City  Country  Salary
# 0   False  False  False  False    False   False
# 1   False  False  False  False    False   False
# 2   False  False  False  False    False   False
# 3   False  False  False  False    False   False
# 4   False  False  False  False    False   False
# 5   False  False  False  False    False   False
# 6   False  False  False  False    False   False
# 7   False  False  False  False    False   False
# 8   False  False  False  False    False   False
# 9   False  False  False  False    False   False
# 10  False  False  False  False    False   False
# 11  False  False  False  False    False   False
# 12  False  False  False  False    False   False
# 13  False  False  False  False    False   False
# 14  False  False  False  False    False   False
# 15  False  False  False  False    False   False
# 16  False  False  False  False    False   False
# 17  False  False  False  False    False   False
# 18  False  False  False  False    False   False
# ...

# %%
df.isnull()
# Out:
#       Name    Age   City  Country  Salary
# SNo
# 1    False  False  False    False   False
# 2    False  False  False    False   False
# 3    False  False  False    False   False
# 4    False  False  False    False   False
# 5    False  False   True    False    True
# 6    False   True  False    False   False
# 7    False  False  False    False   False
# 8    False  False  False    False   False
# 9    False  False  False    False   False
# 11   False   True  False    False   False
# 12   False  False  False    False   False
# 13   False  False   True    False   False
# 14   False  False  False    False   False
# 15   False  False   True    False   False
# 16   False  False  False    False   False
# 17   False   True  False    False   False
# 18   False  False  False    False   False
# 19   False  False  False    False    True
# 20   False  False  False    False   False
# 21   False  False  False    False   False
# 22   False  False  False    False   False
# ...

# %%
df1
# Out:
#     SNo    Name  Age       City  Country Salary
# 0     1     Tom   28    Toronto   Canada  20000
# 1     2     Lee   31    Edmonto   Canada   3900
# 2     3    Dave   34    Toronto   Canada   8000
# 3     4    Anik   26   HongKong     Asia  66672
# 4     5   kamal   30        NaN  America    NaN
# 5     6    Geet  NaN   HongKong     Asia  30007
# 6     7  Steven   43    BayArea  America   8300
# 7     8     Ram   38  Hyderabad     Asia  54666
# 8     9    hari   50    newyork  America  67666
# 9    11    yami  NaN    newyork  America   8888
# 10   12    Anik   26   HongKong     Asia  66672
# 11   13   kamal   30        NaN  America  34344
# 12   14    Geet   22   HongKong     Asia  30007
# 13   15  Steven   43        NaN  America   8300
# 14   16     Ram   38  Hyderabad     Asia  54666
# 15   17    hari  NaN    newyork  America  67666
# 16   18    yami   27    newyork  America   8888
# 17   19     Lee   31    Edmonto   Canada    NaN
# 18   20  Andrew   34      Congo   Africa  34432
# ...

# %%
df1.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        0
# City       0
# Country    0
# Salary     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 9

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1=pd.read_csv("D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\empl.csv")
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df2 = df1.dropna()

# %%
df2
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df2
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df2.dropna(how= 'any')
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df2.dropna(how='all')
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df2.dropna(thresh =1)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df2.dropna(inplace=True)
df2
# Out:
# C:\Users\sagar\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
import numpy as np
import pandas as pd

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.isnull().sum()
# Out:
# SNo        0
# Name       0
# Age        3
# City       3
# Country    0
# Salary     3
# dtype: int64

# %%
df1.fillna(0)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0          0  America      0.0
# 5     6    Geet   0.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   0.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0          0  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0          0  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   0.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna(2)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0          2  America      2.0
# 5     6    Geet   2.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   2.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0          2  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0          2  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   2.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna({'Name':'none','Age':0})
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   0.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   0.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   0.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1['Salary'].mean()
# Out:
# 33739.94736842105

# %%
df1['Salary'].fillna(df1['Salary'].mean())
# Out:
# 0     20000.000000
# 1      3900.000000
# 2      8000.000000
# 3     66672.000000
# 4     33739.947368
# 5     30007.000000
# 6      8300.000000
# 7     54666.000000
# 8     67666.000000
# 9      8888.000000
# 10    66672.000000
# 11    34344.000000
# 12    30007.000000
# 13     8300.000000
# 14    54666.000000
# 15    67666.000000
# 16     8888.000000
# 17    33739.947368
# 18    34432.000000
# 19    34534.000000
# 20    33451.000000
# 21    33739.947368
# Name: Salary, dtype: float64

# %%
df1['Salary'].isnull().sum()
# Out:
# 3

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna(method = 'ffill')
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna(method ='bfill')
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  30007.0
# 5     6    Geet  43.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  26.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0  Hyderabad  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  27.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna(method = 'ffill',axis=0, )
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna(method = 'ffill',axis=1 )
# Out:
#    SNo    Name   Age       City  Country   Salary
# 0    1     Tom    28    Toronto   Canada    20000
# 1    2     Lee    31    Edmonto   Canada     3900
# 2    3    Dave    34    Toronto   Canada     8000
# 3    4    Anik    26   HongKong     Asia    66672
# 4    5   kamal    30         30  America  America
# 5    6    Geet  Geet   HongKong     Asia    30007
# 6    7  Steven    43    BayArea  America     8300
# 7    8     Ram    38  Hyderabad     Asia    54666
# 8    9    hari    50    newyork  America    67666
# 9   11    yami  yami    newyork  America     8888
# 10  12    Anik    26   HongKong     Asia    66672
# 11  13   kamal    30         30  America    34344
# 12  14    Geet    22   HongKong     Asia    30007
# 13  15  Steven    43         43  America     8300
# 14  16     Ram    38  Hyderabad     Asia    54666
# 15  17    hari  hari    newyork  America    67666
# 16  18    yami    27    newyork  America     8888
# 17  19     Lee    31    Edmonto   Canada   Canada
# ...

# %%
df1.fillna(0,limit = 1)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0          0  America      0.0
# 5     6    Geet   0.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.fillna(method= 'ffill', inplace= True)

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df2
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df1.replace(to_replace = 'Finland', value = 'India')
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.replace([1,2,3,4,5],0)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     0     Tom  28.0    Toronto   Canada  20000.0
# 1     0     Lee  31.0    Edmonto   Canada   3900.0
# 2     0    Dave  34.0    Toronto   Canada   8000.0
# 3     0    Anik  26.0   HongKong     Asia  66672.0
# 4     0   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1.replace({'Salary':'Pay'})
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df1
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0   HongKong  America  66672.0
# 5     6    Geet  30.0   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami  50.0    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0   HongKong  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0   HongKong  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari  38.0    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df2
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df.interpolate()
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America  48339.5
# 6      Geet  36.5   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami  38.0    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari  32.5    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada  21660.0
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df.interpolate()
