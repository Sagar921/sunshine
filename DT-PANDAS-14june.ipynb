# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('D:\\empl.csv')
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df = pd.read_csv('D:\\empl.csv', index_col=['SNo'])
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 23
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     22 non-null     object
#  1   Age      19 non-null     float64
#  2   City     19 non-null     object
#  3   Country  22 non-null     object
#  4   Salary   19 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.0+ KB

# %%
df = pd.read_csv('D:\\empl.csv', dtype={'salary': np.float64})
print(df.dtype)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-96b109eb1310> in <module>
#       1 df = pd.read_csv('D:\\empl.csv', dtype={'salary': np.float64})
# ----> 2 print(df.dtype)
#       3 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df['Salary'].max()
# Out:
# 67666.0

# %%
df['Salary'].min()
# Out:
# 3900.0

# %%
df['Salary'].plot()

# %%
df
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
df = pd.read_csv('D:\\empl.csv', index_col=['SNo'])
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1=pd.DataFrame(data=df)

# %%
df1.loc[:,'Salary']
# Out:
# SNo
# 1     20000.0
# 2      3900.0
# 3      8000.0
# 4     66672.0
# 5         NaN
# 6     30007.0
# 7      8300.0
# 8     54666.0
# 9     67666.0
# 11     8888.0
# 12    66672.0
# 13    34344.0
# 14    30007.0
# 15     8300.0
# 16    54666.0
# 17    67666.0
# 18     8888.0
# 19        NaN
# 20    34432.0
# 21    34534.0
# 22    33451.0
# 23        NaN
# Name: Salary, dtype: float64

# %%
df1.loc[:,['Name','Salary']]
# Out:
#        Name   Salary
# SNo
# 1       Tom  20000.0
# 2       Lee   3900.0
# 3      Dave   8000.0
# 4      Anik  66672.0
# 5     kamal      NaN
# 6      Geet  30007.0
# 7    Steven   8300.0
# 8       Ram  54666.0
# 9      hari  67666.0
# 11     yami   8888.0
# 12     Anik  66672.0
# 13    kamal  34344.0
# 14     Geet  30007.0
# 15   Steven   8300.0
# 16      Ram  54666.0
# 17     hari  67666.0
# 18     yami   8888.0
# 19      Lee      NaN
# 20   Andrew  34432.0
# 21    soham  34534.0
# 22     Grig  33451.0
# 23    Kiara      NaN

# %%
df1.iloc[:,1:3]
# Out:
#       Age       City
# SNo
# 1    28.0    Toronto
# 2    31.0    Edmonto
# 3    34.0    Toronto
# 4    26.0   HongKong
# 5    30.0        NaN
# 6     NaN   HongKong
# 7    43.0    BayArea
# 8    38.0  Hyderabad
# 9    50.0    newyork
# 11    NaN    newyork
# 12   26.0   HongKong
# 13   30.0        NaN
# 14   22.0   HongKong
# 15   43.0        NaN
# 16   38.0  Hyderabad
# 17    NaN    newyork
# 18   27.0    newyork
# 19   31.0    Edmonto
# 20   34.0      Congo
# 21   32.0     Angola
# 22   26.0    Finland
# 23   27.0     London

# %%
df.iloc[:,2:4]
# Out:
#           City  Country
# SNo
# 1      Toronto   Canada
# 2      Edmonto   Canada
# 3      Toronto   Canada
# 4     HongKong     Asia
# 5          NaN  America
# 6     HongKong     Asia
# 7      BayArea  America
# 8    Hyderabad     Asia
# 9      newyork  America
# 11     newyork  America
# 12    HongKong     Asia
# 13         NaN  America
# 14    HongKong     Asia
# 15         NaN  America
# 16   Hyderabad     Asia
# 17     newyork  America
# 18     newyork  America
# 19     Edmonto   Canada
# 20       Congo   Africa
# 21      Angola   Africa
# 22     Finland   Europe
# 23      London   Europe

# %%
df1.iloc[:,-1]
# Out:
# SNo
# 1     20000.0
# 2      3900.0
# 3      8000.0
# 4     66672.0
# 5         NaN
# 6     30007.0
# 7      8300.0
# 8     54666.0
# 9     67666.0
# 11     8888.0
# 12    66672.0
# 13    34344.0
# 14    30007.0
# 15     8300.0
# 16    54666.0
# 17    67666.0
# 18     8888.0
# 19        NaN
# 20    34432.0
# 21    34534.0
# 22    33451.0
# 23        NaN
# Name: Salary, dtype: float64

# %%
df1.iloc[1:4,:]
# Out:
#      Name   Age      City Country   Salary
# SNo
# 2     Lee  31.0   Edmonto  Canada   3900.0
# 3    Dave  34.0   Toronto  Canada   8000.0
# 4    Anik  26.0  HongKong    Asia  66672.0

# %%
df1['Name'].describe()
# Out:
# count        22
# unique       14
# top       kamal
# freq          2
# Name: Name, dtype: object

# %%
df1['Salary'].describe()
# Out:
# count       19.000000
# mean     33739.947368
# std      23151.188084
# min       3900.000000
# 25%       8888.000000
# 50%      33451.000000
# 75%      54666.000000
# max      67666.000000
# Name: Salary, dtype: float64

# %%
df1.describe()
# Out:
#              Age        Salary
# count  19.000000     19.000000
# mean   32.421053  33739.947368
# std     7.174924  23151.188084
# min    22.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    31.000000  33451.000000
# 75%    36.000000  54666.000000
# max    50.000000  67666.000000

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'City', 'Country', 'Salary'], dtype='object')

# %%
df1['Country'].describe()
# Out:
# count          22
# unique          5
# top       America
# freq            8
# Name: Country, dtype: object

# %%
df1['Country'].describe()
# Out:
# count          22
# unique          5
# top       America
# freq            8
# Name: Country, dtype: object

# %%
df1['Name'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df1['Country'].unique()
# Out:
# array(['Canada', 'Asia', 'America', 'Africa', 'Europe'], dtype=object)

# %%
df1.describe()
# Out:
#              Age        Salary
# count  19.000000     19.000000
# mean   32.421053  33739.947368
# std     7.174924  23151.188084
# min    22.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    31.000000  33451.000000
# 75%    36.000000  54666.000000
# max    50.000000  67666.000000

# %%
print(df1['Name'].unique())
# Out:
# ['Tom' 'Lee' 'Dave' 'Anik' 'kamal' 'Geet' 'Steven' 'Ram' 'hari' 'yami'
#  'Andrew' 'soham' 'Grig' 'Kiara']

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 23
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     22 non-null     object
#  1   Age      19 non-null     float64
#  2   City     19 non-null     object
#  3   Country  22 non-null     object
#  4   Salary   19 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.0+ KB

# %%
df1.iloc[:,1:4]
# Out:
#       Age       City  Country
# SNo
# 1    28.0    Toronto   Canada
# 2    31.0    Edmonto   Canada
# 3    34.0    Toronto   Canada
# 4    26.0   HongKong     Asia
# 5    30.0        NaN  America
# 6     NaN   HongKong     Asia
# 7    43.0    BayArea  America
# 8    38.0  Hyderabad     Asia
# 9    50.0    newyork  America
# 11    NaN    newyork  America
# 12   26.0   HongKong     Asia
# 13   30.0        NaN  America
# 14   22.0   HongKong     Asia
# 15   43.0        NaN  America
# 16   38.0  Hyderabad     Asia
# 17    NaN    newyork  America
# 18   27.0    newyork  America
# 19   31.0    Edmonto   Canada
# 20   34.0      Congo   Africa
# 21   32.0     Angola   Africa
# 22   26.0    Finland   Europe
# 23   27.0     London   Europe

# %%
df1['Name'].describe()
# Out:
# count        22
# unique       14
# top       kamal
# freq          2
# Name: Name, dtype: object

# %%
print(df1['Name'].unique())
# Out:
# ['Tom' 'Lee' 'Dave' 'Anik' 'kamal' 'Geet' 'Steven' 'Ram' 'hari' 'yami'
#  'Andrew' 'soham' 'Grig' 'Kiara']

# %%
df1.describe()
# Out:
#              Age        Salary
# count  19.000000     19.000000
# mean   32.421053  33739.947368
# std     7.174924  23151.188084
# min    22.000000   3900.000000
# 25%    27.000000   8888.000000
# 50%    31.000000  33451.000000
# 75%    36.000000  54666.000000
# max    50.000000  67666.000000

# %% [markdown]
# Dropping Of Rows And Columns In Pandas

# %%
df1
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df2=df1.drop([14,15,16,17])
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df1
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# ...

# %%
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df.drop([1,2,3], inplace=True)

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df1
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df=df1.drop(['Age', 'Salary'], axis=1, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-295b6a2ba828> in <module>
# ----> 1 df=df1.drop(['Age', 'Salary'], axis=1, inplace=True)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df1
# Out:
#        Name       City  Country
# SNo
# 4      Anik   HongKong     Asia
# 5     kamal        NaN  America
# 6      Geet   HongKong     Asia
# 7    Steven    BayArea  America
# 8       Ram  Hyderabad     Asia
# 9      hari    newyork  America
# 11     yami    newyork  America
# 12     Anik   HongKong     Asia
# 13    kamal        NaN  America
# 14     Geet   HongKong     Asia
# 15   Steven        NaN  America
# 16      Ram  Hyderabad     Asia
# 17     hari    newyork  America
# 18     yami    newyork  America
# 19      Lee    Edmonto   Canada
# 20   Andrew      Congo   Africa
# 21    soham     Angola   Africa
# 22     Grig    Finland   Europe
# 23    Kiara     London   Europe

# %%
df1
# Out:
#        Name       City  Country
# SNo
# 4      Anik   HongKong     Asia
# 5     kamal        NaN  America
# 6      Geet   HongKong     Asia
# 7    Steven    BayArea  America
# 8       Ram  Hyderabad     Asia
# 9      hari    newyork  America
# 11     yami    newyork  America
# 12     Anik   HongKong     Asia
# 13    kamal        NaN  America
# 14     Geet   HongKong     Asia
# 15   Steven        NaN  America
# 16      Ram  Hyderabad     Asia
# 17     hari    newyork  America
# 18     yami    newyork  America
# 19      Lee    Edmonto   Canada
# 20   Andrew      Congo   Africa
# 21    soham     Angola   Africa
# 22     Grig    Finland   Europe
# 23    Kiara     London   Europe

# %%
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df1
# Out:
#        Name       City  Country
# SNo
# 4      Anik   HongKong     Asia
# 5     kamal        NaN  America
# 6      Geet   HongKong     Asia
# 7    Steven    BayArea  America
# 8       Ram  Hyderabad     Asia
# 9      hari    newyork  America
# 11     yami    newyork  America
# 12     Anik   HongKong     Asia
# 13    kamal        NaN  America
# 14     Geet   HongKong     Asia
# 15   Steven        NaN  America
# 16      Ram  Hyderabad     Asia
# 17     hari    newyork  America
# 18     yami    newyork  America
# 19      Lee    Edmonto   Canada
# 20   Andrew      Congo   Africa
# 21    soham     Angola   Africa
# 22     Grig    Finland   Europe
# 23    Kiara     London   Europe

# %%
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 1 to 23
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     18 non-null     object
#  1   Age      16 non-null     float64
#  2   City     16 non-null     object
#  3   Country  18 non-null     object
#  4   Salary   15 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 864.0+ bytes

# %%
df2.iloc[:,1:3]
# Out:
#       Age       City
# SNo
# 1    28.0    Toronto
# 2    31.0    Edmonto
# 3    34.0    Toronto
# 4    26.0   HongKong
# 5    30.0        NaN
# 6     NaN   HongKong
# 7    43.0    BayArea
# 8    38.0  Hyderabad
# 9    50.0    newyork
# 11    NaN    newyork
# 12   26.0   HongKong
# 13   30.0        NaN
# 18   27.0    newyork
# 19   31.0    Edmonto
# 20   34.0      Congo
# 21   32.0     Angola
# 22   26.0    Finland
# 23   27.0     London

# %%
df2['Salary'].describe()
# Out:
# count       15.000000
# mean     32028.000000
# std      22918.537684
# min       3900.000000
# 25%       8888.000000
# 50%      33451.000000
# 75%      44600.000000
# max      67666.000000
# Name: Salary, dtype: float64

# %%
df2.min()
# Out:
# Name       Andrew
# Age            26
# Country    Africa
# Salary       3900
# dtype: object

# %%
df2['Salary'].min()
# Out:
# 3900.0

# %%
df2.max()
# Out:
# Name         yami
# Age            50
# Country    Europe
# Salary      67666
# dtype: object

# %%
df2['Salary'].max()
# Out:
# 67666.0

# %%
df2['Name'].unique()
# Out:
# array(['Tom', 'Lee', 'Dave', 'Anik', 'kamal', 'Geet', 'Steven', 'Ram',
#        'hari', 'yami', 'Andrew', 'soham', 'Grig', 'Kiara'], dtype=object)

# %%
df1
# Out:
#        Name       City  Country
# SNo
# 4      Anik   HongKong     Asia
# 5     kamal        NaN  America
# 6      Geet   HongKong     Asia
# 7    Steven    BayArea  America
# 8       Ram  Hyderabad     Asia
# 9      hari    newyork  America
# 11     yami    newyork  America
# 12     Anik   HongKong     Asia
# 13    kamal        NaN  America
# 14     Geet   HongKong     Asia
# 15   Steven        NaN  America
# 16      Ram  Hyderabad     Asia
# 17     hari    newyork  America
# 18     yami    newyork  America
# 19      Lee    Edmonto   Canada
# 20   Andrew      Congo   Africa
# 21    soham     Angola   Africa
# 22     Grig    Finland   Europe
# 23    Kiara     London   Europe

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 14     Geet  22.0   HongKong     Asia  30007.0
# 15   Steven  43.0        NaN  America   8300.0
# 16      Ram  38.0  Hyderabad     Asia  54666.0
# 17     hari   NaN    newyork  America  67666.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
df1
# Out:
#        Name       City  Country
# SNo
# 4      Anik   HongKong     Asia
# 5     kamal        NaN  America
# 6      Geet   HongKong     Asia
# 7    Steven    BayArea  America
# 8       Ram  Hyderabad     Asia
# 9      hari    newyork  America
# 11     yami    newyork  America
# 12     Anik   HongKong     Asia
# 13    kamal        NaN  America
# 14     Geet   HongKong     Asia
# 15   Steven        NaN  America
# 16      Ram  Hyderabad     Asia
# 17     hari    newyork  America
# 18     yami    newyork  America
# 19      Lee    Edmonto   Canada
# 20   Andrew      Congo   Africa
# 21    soham     Angola   Africa
# 22     Grig    Finland   Europe
# 23    Kiara     London   Europe

# %%
df2
# Out:
#        Name   Age       City  Country   Salary
# SNo
# 1       Tom  28.0    Toronto   Canada  20000.0
# 2       Lee  31.0    Edmonto   Canada   3900.0
# 3      Dave  34.0    Toronto   Canada   8000.0
# 4      Anik  26.0   HongKong     Asia  66672.0
# 5     kamal  30.0        NaN  America      NaN
# 6      Geet   NaN   HongKong     Asia  30007.0
# 7    Steven  43.0    BayArea  America   8300.0
# 8       Ram  38.0  Hyderabad     Asia  54666.0
# 9      hari  50.0    newyork  America  67666.0
# 11     yami   NaN    newyork  America   8888.0
# 12     Anik  26.0   HongKong     Asia  66672.0
# 13    kamal  30.0        NaN  America  34344.0
# 18     yami  27.0    newyork  America   8888.0
# 19      Lee  31.0    Edmonto   Canada      NaN
# 20   Andrew  34.0      Congo   Africa  34432.0
# 21    soham  32.0     Angola   Africa  34534.0
# 22     Grig  26.0    Finland   Europe  33451.0
# 23    Kiara  27.0     London   Europe      NaN

# %%
country = pd.read_csv('D:\\empl.csv', index_col=0)

country.to_html('emp1test.html')

# %%
ab=pd.read_csv('D:\\DATA-TRAINED\\dataset1-master\\dataset1-master\\service_dataset.csv')
ab
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1     26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2     26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3     26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4     26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# 5     26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 6     26595682  10/31/2013 01:46:40 AM                     NaN   NYPD
# 7     26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# 8     26590540  10/31/2013 01:44:14 AM  10/31/2013 02:28:04 AM   NYPD
# 9     26594392  10/31/2013 01:34:41 AM  10/31/2013 02:23:51 AM   NYPD
# 10    26595176  10/31/2013 01:25:12 AM                     NaN   NYPD
# 11    26591982  10/31/2013 01:24:14 AM  10/31/2013 01:54:39 AM   NYPD
# ...

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unique Key             49 non-null     int64
#  1   Created Date           49 non-null     object
#  2   Closed Date            24 non-null     object
#  3   Agency                 49 non-null     object
#  4   Agency Name            49 non-null     object
#  5   Complaint Type         49 non-null     object
#  6   Descriptor             48 non-null     object
#  7   Location Type          42 non-null     object
#  8   Incident Zip           47 non-null     float64
#  9   Incident Address       40 non-null     object
#  10  Street Name            40 non-null     object
#  11  Cross Street 1         38 non-null     object
#  12  Cross Street 2         38 non-null     object
#  13  Intersection Street 1  9 non-null      object
# ...

# %%
ab.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type  Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk       11432.0
# ...

# %%
ab['Complaint Type']
# Out:
# 0      Noise - Street/Sidewalk
# 1              Illegal Parking
# 2           Noise - Commercial
# 3              Noise - Vehicle
# 4                       Rodent
# 5           Noise - Commercial
# 6             Blocked Driveway
# 7           Noise - Commercial
# 8           Noise - Commercial
# 9           Noise - Commercial
# 10    Noise - House of Worship
# 11          Noise - Commercial
# 12             Illegal Parking
# 13             Noise - Vehicle
# 14                      Rodent
# 15    Noise - House of Worship
# 16     Noise - Street/Sidewalk
# 17             Illegal Parking
# 18      Street Light Condition
# 19          Noise - Commercial
# 20    Noise - House of Worship
# 21          Noise - Commercial
# 22             Noise - Vehicle
# 23          Noise - Commercial
# 24            Blocked Driveway
# 25     Noise - Street/Sidewalk
# 26      Street Light Condition
# 27        Harboring Bees/Wasps
# 28     Noise - Street/Sidewalk
# 29      Street Light Condition
# ...

# %%
ab['Complaint Type'].describe()
# Out:
# count                     49
# unique                    14
# top       Noise - Commercial
# freq                      15
# Name: Complaint Type, dtype: object

# %%
ab.describe()
# Out:
#          Unique Key  Incident Zip
# count  4.900000e+01     47.000000
# mean   2.659260e+07  10656.170213
# std    2.028985e+03    592.289013
# min    2.658920e+07  10003.000000
# 25%    2.659092e+07  10028.000000
# 50%    2.659237e+07  10459.000000
# 75%    2.659417e+07  11232.500000
# max    2.659594e+07  11433.000000

# %%
ab
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1     26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2     26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3     26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4     26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# 5     26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 6     26595682  10/31/2013 01:46:40 AM                     NaN   NYPD
# 7     26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# 8     26590540  10/31/2013 01:44:14 AM  10/31/2013 02:28:04 AM   NYPD
# 9     26594392  10/31/2013 01:34:41 AM  10/31/2013 02:23:51 AM   NYPD
# 10    26595176  10/31/2013 01:25:12 AM                     NaN   NYPD
# 11    26591982  10/31/2013 01:24:14 AM  10/31/2013 01:54:39 AM   NYPD
# ...

# %%
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unique Key             49 non-null     int64
#  1   Created Date           49 non-null     object
#  2   Closed Date            24 non-null     object
#  3   Agency                 49 non-null     object
#  4   Agency Name            49 non-null     object
#  5   Complaint Type         49 non-null     object
#  6   Descriptor             48 non-null     object
#  7   Location Type          42 non-null     object
#  8   Incident Zip           47 non-null     float64
#  9   Incident Address       40 non-null     object
#  10  Street Name            40 non-null     object
#  11  Cross Street 1         38 non-null     object
#  12  Cross Street 2         38 non-null     object
#  13  Intersection Street 1  9 non-null      object
# ...

# %%
ab.isnull().sum()
# Out:
# Unique Key                0
# Created Date              0
# Closed Date              25
# Agency                    0
# Agency Name               0
# Complaint Type            0
# Descriptor                1
# Location Type             7
# Incident Zip              2
# Incident Address          9
# Street Name               9
# Cross Street 1           11
# Cross Street 2           11
# Intersection Street 1    40
# Intersection Street 2    40
# Address Type              0
# City                      2
# dtype: int64
